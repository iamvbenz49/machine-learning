# %%
import numpy as np

# %%
array = np.array([[1,2],[3,4]])
array
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
#acessing an array
array[0]
# Out:
# array([1, 2])

# %%
array[0][1:], array.shape
# Out:
# (array([2]), (2, 2))

# %%
#another way to acess index
array[0,1]
# Out:
# 2

# %%
#acessing 3d array
array3d = np.array([[[1,3,4],[5,6,7]],[[8,9,8],[7,6,5]]])
array3d
# Out:
# array([[[1, 3, 4],
#         [5, 6, 7]],
#
#        [[8, 9, 8],
#         [7, 6, 5]]])

# %%
array3d[1,1,2]
# Out:
# 5
