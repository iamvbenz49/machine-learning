# %%
import numpy as np

# %%
ones_array = np.array([[1,2,3],[4,5,6]])
ones_array + [1,5,7]
# Out:
# array([[ 2,  7, 10],
#        [ 5, 10, 13]])

# %%
ones_array + [[1,5,7],[7,8,9]]
# Out:
# array([[ 2,  7, 10],
#        [11, 13, 15]])
